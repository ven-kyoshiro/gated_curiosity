# %% [markdown]
# - 先ずは変数毎の正規化を入れないとおかしくないですか？
# -
# # pickleに吐いて，可視化
# - 誤差が下がるようす
# - エピソード毎の報酬の経過

# %%
ll
# Out:
# total 53388
# -rw-r--r-- 1 shigeharu    20277 Dec  4 18:24 curio_dqn.py
# -rw-r--r-- 1 shigeharu     1724 Dec  3 11:08 double_dqn.py
# -rw-r--r-- 1 shigeharu    11402 Dec  2 12:36 example.ipynb
# -rw-r--r-- 1 shigeharu     4529 Dec  2 21:34 graph2.dot
# -rw-r--r-- 1 shigeharu     4894 Dec  2 20:53 graph.dot
# -rw-r--r-- 1 shigeharu    41960 Dec  3 01:41 hard_cartpole.ipynb
# -rw-r--r-- 1 shigeharu     8451 Dec  4 17:55 hard_cartpole.py
# -rw-r--r-- 1 shigeharu    69560 Dec  4 21:09 health_check.ipynb
# -rw-r--r-- 1 shigeharu  3508743 Dec  3 11:51 intrinsic_motivation.ipynb
# drwxr-xr-x 2 shigeharu      512 Dec  3 11:05 old_testcode/
# drwxr-xr-x 2 shigeharu      512 Dec  4 18:27 __pycache__/
# -rw-r--r-- 1 shigeharu     4808 Dec  4 17:56 test_code5.py
# -rw-r--r-- 1 shigeharu     4808 Dec  4 18:30 test_code6.py
# -rw-r--r-- 1 shigeharu     4688 Dec  3 11:55 test_rec01_std100_loop10.pickle
# -rw-r--r-- 1 shigeharu     4499 Dec  3 11:55 test_rec02_std10_loop10.pickle
# -rw-r--r-- 1 shigeharu    18010 Dec  3 13:31 test_rec03_std1000000000000_loop1.pickle
# -rw-r--r-- 1 shigeharu 21552372 Dec  4 20:51 test_rec05_std100_loop20.pickle
# -rw-r--r-- 1 shigeharu  7345625 Dec  4 18:11 test_rec05_std10_loop20.pickle
# -rw-r--r-- 1 shigeharu 21803851 Dec  4 21:08 test_rec06_std100_loop20.pickle

# %%
import pickle

# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
with open("test_rec06_std100_loop20.pickle",mode='rb') as f:
    data = pickle.load(f)
plt.plot(list(range(len(data["qt+i_r"]))), [float(sum(d.array)/len(d.array)) for d in data["qt+i_r"]])

# %%
plt.plot(list(range(len(data['loss']))), [float(d.array) for d in data['loss']])

# %%
plt.plot(list(range(len(data['reward']))), data['reward'])

# %%
# 報酬がはじで赤になってる感じのやつを見せたい，

# %%
import math
def draw_int_rew(data,i):
    plt.figure(figsize=(12, 10))
    x = [math.sin(rad) for rad in data['target'][i]]
    y = [math.cos(rad) for rad in data['target'][i]]
    losses = [d[0] for d in data['target_losses'][i]]
    #vmin = min(losses)
    #vmax = max(losses)
    plt.xlim(-1.1, 1.1)
    plt.ylim(-1.1,1.1)
    plt.scatter(x,y,cmap='rainbow',c=losses)
    plt.colorbar()

# %%
len(data['target_losses'])
# Out:
# 8014

# %%
draw_int_rew(data,0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-6f42c6597387> in <module>()
# ----> 1 draw_int_rew(data,0)
#
# <ipython-input-62-b0e1be174cbc> in draw_int_rew(data, i)
#       7     #vmin = min(losses)
#       8     #vmax = max(losses)
# ----> 9     plt.xlim(-1.1, 1.1)
#      10     plt.ylim(-1.1,1.1)
#      11     plt.scatter(x,y,cmap='rainbow',c=losses)
#
# TypeError: 'tuple' object is not callable

# %%
# Out:
# array([ 2.7219303, -3.1269526, -2.767725 ,  2.15571  , -2.755028 ,
#        -2.2303708,  2.677519 , -2.8083076,  2.585791 , -2.7740977,
#        -2.5500185,  2.6583366, -3.1325903, -3.1325784,  2.739721 ,
#         2.4752772, -3.01134  , -1.5827022,  2.960523 , -2.2328136,
#        -3.01451  , -2.9772236, -2.6353886, -2.8283546, -2.3199878,
#         3.1005812,  3.107458 , -1.4369209, -2.3510675,  2.6369421,
#         2.8368447, -2.863806 ], dtype=float32)
